# %% [markdown]
# # Text Completion Project Using LSTM & RNN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("qoute_dataset.csv")

# %%
df.head()
# Out:
#                                                quote           Author
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe

# %%
df["quote"][0]
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
df.shape
# Out:
# (3038, 2)

# %%
quotes = df["quote"]
quotes.head()
# Out:
# 0    “The world as we have created it is a process ...
# 1    “It is our choices, Harry, that show what we t...
# 2    “There are only two ways to live your life. On...
# 3    “The person, be it gentleman or lady, who has ...
# 4    “Imperfection is beauty, madness is genius and...
# Name: quote, dtype: object

# %%
quotes = quotes.str.lower()

# %%
import string
translator = str.maketrans("","",string.punctuation)
quotes = quotes.apply(lambda x: x.translate(translator))

# %%
quotes.head()
# Out:
# 0    “the world as we have created it is a process ...
# 1    “it is our choices harry that show what we tru...
# 2    “there are only two ways to live your life one...
# 3    “the person be it gentleman or lady who has no...
# 4    “imperfection is beauty madness is genius and ...
# Name: quote, dtype: object

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
vocab_size = 10000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(quotes)

# %%
word_index = tokenizer.word_index
print(len(word_index))
list(word_index.items())[:10]
# Out:
# 8979
# [('<OOV>', 1),
#  ('the', 2),
#  ('you', 3),
#  ('to', 4),
#  ('and', 5),
#  ('a', 6),
#  ('i', 7),
#  ('is', 8),
#  ('of', 9),
#  ('that', 10)]

# %%
sequence = tokenizer.texts_to_sequences(quotes)

# %%
for i in range(3):
    print(quotes[i])
# Out:
# “the world as we have created it is a process of our thinking it cannot be changed without changing our thinking”
# “it is our choices harry that show what we truly are far more than our abilities”
# “there are only two ways to live your life one is as though nothing is a miracle the other is as though everything is a miracle”

# %%
for i in range(3):
    print(sequence[i])
# Out:
# [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11, 146, 13, 810, 105, 753, 71, 2462]
# [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15, 295, 53, 55, 71, 3677]
# [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94, 8, 6, 1158, 2, 102, 8, 30, 330, 127, 8, 6, 3678]

# %%
X = []
y = []

for seq in sequence:
    for i in range(1,len(seq)):
        input_seq = seq[:i]
        output_seq = seq[i]
        X.append(input_seq)
        y.append(output_seq)

# %%
X
# Out:
# [[714],
#  [714, 63],
#  [714, 63, 30],
#  [714, 63, 30, 20],
#  [714, 63, 30, 20, 17],
#  [714, 63, 30, 20, 17, 947],
#  [714, 63, 30, 20, 17, 947, 11],
#  [714, 63, 30, 20, 17, 947, 11, 8],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11, 146],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11, 146, 13],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11, 146, 13, 810],
#  [714, 63, 30, 20, 17, 947, 11, 8, 6, 1157, 9, 71, 294, 11, 146, 13, 810, 105],
#  [714,
#   63,
#   30,
#   20,
#   17,
#   947,
#   11,
#   8,
#   6,
#   1157,
#   9,
#   71,
#   294,
#   11,
#   146,
#   13,
#   810,
#   105,
#   753],
#  [714,
#   63,
#   30,
#   20,
#   17,
#   947,
#   11,
#   8,
#   6,
#   1157,
#   9,
#   71,
#   294,
#   11,
#   146,
#   13,
#   810,
#   105,
#   753,
#   71],
#  [948],
#  [948, 8],
#  [948, 8, 71],
#  [948, 8, 71, 872],
#  [948, 8, 71, 872, 374],
#  [948, 8, 71, 872, 374, 10],
#  [948, 8, 71, 872, 374, 10, 434],
#  [948, 8, 71, 872, 374, 10, 434, 22],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15, 295],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15, 295, 53],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15, 295, 53, 55],
#  [948, 8, 71, 872, 374, 10, 434, 22, 20, 466, 15, 295, 53, 55, 71],
#  [1338],
#  [1338, 15],
#  [1338, 15, 54],
#  [1338, 15, 54, 202],
#  [1338, 15, 54, 202, 715],
#  [1338, 15, 54, 202, 715, 4],
#  [1338, 15, 54, 202, 715, 4, 82],
#  [1338, 15, 54, 202, 715, 4, 82, 16],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94, 8],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94, 8, 6],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94, 8, 6, 1158],
#  [1338, 15, 54, 202, 715, 4, 82, 16, 37, 38, 8, 30, 330, 94, 8, 6, 1158, 2],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8,
#   30],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8,
#   30,
#   330],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8,
#   30,
#   330,
#   127],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8,
#   30,
#   330,
#   127,
#   8],
#  [1338,
#   15,
#   54,
#   202,
#   715,
#   4,
#   82,
#   16,
#   37,
#   38,
#   8,
#   30,
#   330,
#   94,
#   8,
#   6,
#   1158,
#   2,
#   102,
#   8,
#   30,
#   330,
#   127,
#   8,
#   6],
#  [714],
#  [714, 117],
#  [714, 117, 13],
#  [714, 117, 13, 11],
#  [714, 117, 13, 11, 2463],
#  [714, 117, 13, 11, 2463, 33],
#  [714, 117, 13, 11, 2463, 33, 1044],
#  [714, 117, 13, 11, 2463, 33, 1044, 31],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12, 6],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12, 6, 75],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12, 6, 75, 1339],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12, 6, 75, 1339, 120],
#  [714, 117, 13, 11, 2463, 33, 1044, 31, 83, 14, 602, 12, 6, 75, 1339, 120, 13],
#  [714,
#   117,
#   13,
#   11,
#   2463,
#   33,
#   1044,
#   31,
#   83,
#   14,
#   602,
#   12,
#   6,
#   75,
#   1339,
#   120,
#   13,
#   2464],
#  [3680],
#  [3680, 8],
#  [3680, 8, 314],
#  [3680, 8, 314, 754],
#  [3680, 8, 314, 754, 8],
#  [3680, 8, 314, 754, 8, 639],
#  [3680, 8, 314, 754, 8, 639, 5],
#  [3680, 8, 314, 754, 8, 639, 5, 44],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4, 13],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4, 13, 683],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4, 13, 683, 1340],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4, 13, 683, 1340, 55],
#  [3680, 8, 314, 754, 8, 639, 5, 44, 145, 4, 13, 683, 1340, 55, 683],
#  [3682],
#  [3682, 14],
#  [3682, 14, 4],
#  [3682, 14, 4, 203],
#  [3682, 14, 4, 203, 6],
#  [3682, 14, 4, 203, 6, 91],
#  [3682, 14, 4, 203, 6, 91, 9],
#  [3682, 14, 4, 203, 6, 91, 9, 435],
#  [3682, 14, 4, 203, 6, 91, 9, 435, 280],
#  [3682, 14, 4, 203, 6, 91, 9, 435, 280, 203],
#  [3682, 14, 4, 203, 6, 91, 9, 435, 280, 203, 6],
#  [3682, 14, 4, 203, 6, 91, 9, 435, 280, 203, 6, 91],
#  [3682, 14, 4, 203, 6, 91, 9, 435, 280, 203, 6, 91, 9],
#  [948],
#  [948, 8],
#  [948, 8, 145],
#  [948, 8, 145, 4],
#  [948, 8, 145, 4, 13],
#  [948, 8, 145, 4, 13, 1341],
#  [948, 8, 145, 4, 13, 1341, 18],
#  [948, 8, 145, 4, 13, 1341, 18, 22],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13, 176],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13, 176, 18],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13, 176, 18, 22],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13, 176, 18, 22, 3],
#  [948, 8, 145, 4, 13, 1341, 18, 22, 3, 15, 55, 4, 13, 176, 18, 22, 3, 15],
#  [716],
#  [716, 17],
#  [716, 17, 14],
#  [716, 17, 14, 1342],
#  [716, 17, 14, 1342, 192],
#  [716, 17, 14, 1342, 192, 52],
#  [716, 17, 14, 1342, 192, 52, 416],
#  [716, 17, 14, 1342, 192, 52, 416, 2465],
#  [716, 17, 14, 1342, 192, 52, 416, 2465, 715],
#  [716, 17, 14, 1342, 192, 52, 416, 2465, 715, 10],
#  [716, 17, 14, 1342, 192, 52, 416, 2465, 715, 10, 364],
#  [1045],
#  [1045, 181],
#  [1045, 181, 8],
#  [1045, 181, 8, 40],
#  [1045, 181, 8, 40, 6],
#  [1045, 181, 8, 40, 6, 811],
#  [1045, 181, 8, 40, 6, 811, 1343],
#  [1045, 181, 8, 40, 6, 811, 1343, 3],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11, 8],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11, 8, 169],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11, 8, 169, 44],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11, 8, 169, 44, 12],
#  [1045, 181, 8, 40, 6, 811, 1343, 3, 47, 51, 60, 323, 11, 8, 169, 44, 12, 640],
#  [1045],
#  [1045, 112],
#  [1045, 112, 105],
#  [1045, 112, 105, 1046],
#  [1045, 112, 105, 1046, 8],
#  [1045, 112, 105, 1046, 8, 40],
#  [1045, 112, 105, 1046, 8, 40, 3],
#  [1045, 112, 105, 1046, 8, 40, 3, 51],
#  [2466],
#  [2466, 37],
#  [2466, 37, 8],
#  [2466, 37, 8, 22],
#  [2466, 37, 8, 22, 3],
#  [2466, 37, 8, 22, 3, 66],
#  [2466, 37, 8, 22, 3, 66, 11],
#  [2466, 37, 8, 22, 3, 66, 11, 48],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4, 755],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4, 755, 59],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4, 755, 59, 124],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4, 755, 59, 124, 44],
#  [2466, 37, 8, 22, 3, 66, 11, 48, 182, 22, 97, 131, 4, 755, 59, 124, 44, 6],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4,
#   391],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4,
#   391,
#   16],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4,
#   391,
#   16,
#   93],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4,
#   391,
#   16,
#   93,
#   19],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
#   48,
#   182,
#   22,
#   97,
#   131,
#   4,
#   755,
#   59,
#   124,
#   44,
#   6,
#   1940,
#   175,
#   19,
#   2,
#   75,
#   209,
#   8,
#   3,
#   95,
#   4,
#   467,
#   60,
#   97,
#   131,
#   4,
#   755,
#   11,
#   59,
#   517,
#   29,
#   13,
#   16,
#   213,
#   949,
#   518,
#   40,
#   11,
#   812,
#   19,
#   52,
#   159,
#   90,
#   133,
#   90,
#   80,
#   2,
#   235,
#   10,
#   272,
#   23,
#   3,
#   147,
#   127,
#   273,
#   16,
#   162,
#   160,
#   213,
#   50,
#   103,
#   80,
#   9,
#   49,
#   390,
#   159,
#   2467,
#   66,
#   2,
#   160,
#   213,
#   12,
#   2,
#   63,
#   30,
#   18,
#   1344,
#   168,
#   949,
#   133,
#   5,
#   80,
#   86,
#   5,
#   813,
#   7,
#   274,
#   4,
#   119,
#   11,
#   118,
#   9,
#   49,
#   483,
#   417,
#   106,
#   24,
#   9,
#   49,
#   15,
#   131,
#   4,
#   391,
#   16,
#   93,
#   19,
#   3],
#  [2466,
#   37,
#   8,
#   22,
#   3,
#   66,
#   11,
# ...
#   121,
#   41,
#   8,
#   48,
#   7,
#   33,
#   3,
#   46,
#   1345,
#   10,
#   16,
#   316,
#   245,
#   27,
#   759,
#   8,
#   27,
#   316,
#   46,
#   1345,
#   10,
#   28,
#   7,
#   229],
#  [716,
#   25,
#   3,
#   105,
#   365,
#   60,
#   33,
#   28,
#   33,
#   69,
#   136,
#   7,
#   25,
#   3,
#   577,
#   105,
#   818,
#   33,
#   878,
#   7,
#   25,
#   3,
#   12,
#   57,
#   79,
#   56,
#   7,
#   32,
#   14,
#   51,
#   149,
#   102,
#   79,
#   9,
#   393,
#   19,
#   57,
#   12,
#   121,
#   41,
#   8,
#   48,
#   7,
#   33,
#   3,
#   46,
#   1345,
#   10,
#   16,
#   316,
#   245,
#   27,
#   759,
#   8,
#   27,
#   316,
#   46,
#   1345,
#   10,
#   28,
#   7,
#   229,
#   685],
#  [716,
#   25,
#   3,
#   105,
#   365,
#   60,
#   33,
#   28,
#   33,
#   69,
#   136,
#   7,
#   25,
#   3,
#   577,
#   105,
#   818,
#   33,
#   878,
#   7,
#   25,
#   3,
#   12,
#   57,
#   79,
#   56,
#   7,
#   32,
#   14,
#   51,
#   149,
#   102,
#   79,
#   9,
#   393,
#   19,
#   57,
#   12,
#   121,
#   41,
#   8,
#   48,
#   7,
#   33,
#   3,
#   46,
#   1345,
#   10,
#   16,
#   316,
#   245,
#   27,
#   759,
#   8,
#   27,
#   316,
#   46,
#   1345,
#   10,
#   28,
#   7,
#   229,
#   685,
#   16],
#  [716,
#   25,
#   3,
#   105,
#   365,
#   60,
#   33,
#   28,
#   33,
#   69,
#   136,
#   7,
#   25,
#   3,
#   577,
#   105,
#   818,
#   33,
#   878,
#   7,
#   25,
#   3,
#   12,
#   57,
#   79,
#   56,
#   7,
#   32,
#   14,
#   51,
#   149,
#   102,
#   79,
#   9,
#   393,
#   19,
#   57,
#   12,
#   121,
#   41,
#   8,
#   48,
#   7,
#   33,
#   3,
#   46,
#   1345,
#   10,
#   16,
#   316,
#   245,
#   27,
#   759,
#   8,
#   27,
#   316,
#   46,
#   1345,
#   10,
#   28,
#   7,
#   229,
#   685,
#   16,
#   223],
#  [3697],
#  [3697, 88],
#  [3697, 88, 642],
#  [3697, 88, 642, 3],
#  [3697, 88, 642, 3, 15],
#  [3697, 88, 642, 3, 15, 760],
#  [3697, 88, 642, 3, 15, 760, 3],
#  [3697, 88, 642, 3, 15, 760, 3, 240],
#  [3697, 88, 642, 3, 15, 760, 3, 240, 1949],
#  [3697, 88, 642, 3, 15, 760, 3, 240, 1949, 1346],
#  [3697, 88, 642, 3, 15, 760, 3, 240, 1949, 1346, 9],
#  [1048],
#  [1048, 3],
#  [1048, 3, 717],
#  [1048, 3, 717, 42],
#  [1048, 3, 717, 42, 3],
#  [1048, 3, 717, 42, 3, 17],
#  [1048, 3, 717, 42, 3, 17, 48],
#  [1048, 3, 717, 42, 3, 17, 48, 68],
#  [1048, 3, 717, 42, 3, 17, 48, 68, 4],
#  [1048, 3, 717, 42, 3, 17, 48, 68, 4, 25],
#  [2476],
#  [2476, 31],
#  [2476, 31, 578],
#  [2476, 31, 578, 955],
#  [2476, 31, 578, 955, 12],
#  [2476, 31, 578, 955, 12, 1575],
#  [2476, 31, 578, 955, 12, 1575, 26],
#  [2476, 31, 578, 955, 12, 1575, 26, 66],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120, 390],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120, 390, 65],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120, 390, 65, 10],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120, 390, 65, 10, 955],
#  [2476, 31, 578, 955, 12, 1575, 26, 66, 3, 6, 1576, 120, 390, 65, 10, 955, 12],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6,
#   1950],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6,
#   1950,
#   26],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6,
#   1950,
#   26,
#   66],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6,
#   1950,
#   26,
#   66,
#   3],
#  [2476,
#   31,
#   578,
#   955,
#   12,
#   1575,
#   26,
#   66,
#   3,
#   6,
#   1576,
#   120,
#   390,
#   65,
#   10,
#   955,
#   12,
#   6,
#   1950,
#   26,
#   66,
#   3,
#   6],
#  [3701],
#  [3701, 8],
#  [3701, 8, 12],
#  [3701, 8, 12, 2],
#  [3701, 8, 12, 2, 718],
#  [3701, 8, 12, 2, 718, 9],
#  [3701, 8, 12, 2, 718, 9, 2],
#  [3701, 8, 12, 2, 718, 9, 2, 1577],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69, 68],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69, 68, 4],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69, 68, 4, 68],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69, 68, 4, 68, 4],
#  [3701, 8, 12, 2, 718, 9, 2, 1577, 5, 11, 135, 13, 605, 69, 68, 4, 68, 4, 134],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347,
#   33],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347,
#   33,
#   1578],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347,
#   33,
#   1578,
#   1577],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347,
#   33,
#   1578,
#   1577,
#   6],
#  [3701,
#   8,
#   12,
#   2,
#   718,
#   9,
#   2,
#   1577,
#   5,
#   11,
#   135,
#   13,
#   605,
#   69,
#   68,
#   4,
#   68,
#   4,
#   134,
#   6,
#   347,
#   33,
#   1578,
#   1577,
#   6,
#   469],
#  [3703],
#  [3703, 3],
#  [3703, 3, 15],
#  [3703, 3, 15, 3],
#  [3703, 3, 15, 3, 10],
#  [3703, 3, 15, 3, 10, 8],
#  [3703, 3, 15, 3, 10, 8, 1951],
#  [3703, 3, 15, 3, 10, 8, 1951, 55],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38, 394],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38, 394, 31],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38, 394, 31, 8],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38, 394, 31, 8, 2477],
#  [3703, 3, 15, 3, 10, 8, 1951, 55, 162, 41, 8, 48, 38, 394, 31, 8, 2477, 55],
#  [1048],
#  [1048, 3],
#  [1048, 3, 58],
#  [1048, 3, 58, 16],
#  [1048, 3, 58, 16, 348],
#  [1048, 3, 58, 16, 348, 4],
#  [1048, 3, 58, 16, 348, 4, 13],
#  [1048, 3, 58, 16, 348, 4, 13, 579],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21, 3],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21, 3, 58],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21, 3, 58, 49],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21, 3, 58, 49, 4],
#  [1048, 3, 58, 16, 348, 4, 13, 579, 125, 49, 686, 687, 21, 3, 58, 49, 4, 13],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53,
#   579],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53,
#   579,
#   125],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53,
#   579,
#   125,
#   49],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53,
#   579,
#   125,
#   49,
#   53],
#  [1048,
#   3,
#   58,
#   16,
#   348,
#   4,
#   13,
#   579,
#   125,
#   49,
#   686,
#   687,
#   21,
#   3,
#   58,
#   49,
#   4,
#   13,
#   53,
#   579,
#   125,
#   49,
#   53,
#   686],
#  [948],
#  [948, 8],
#  [948, 8, 375],
#  [948, 8, 375, 4],
#  [948, 8, 375, 4, 82],
#  [948, 8, 375, 4, 82, 105],
#  [948, 8, 375, 4, 82, 105, 1579],
#  [948, 8, 375, 4, 82, 105, 1579, 45],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46, 2479],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46, 2479, 10],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46, 2479, 10, 3],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46, 2479, 10, 3, 254],
#  [948, 8, 375, 4, 82, 105, 1579, 45, 84, 470, 3, 82, 46, 2479, 10, 3, 254, 30],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12,
#   121],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12,
#   121,
#   819],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12,
#   121,
#   819,
#   3],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12,
#   121,
#   819,
#   3,
#   684],
#  [948,
#   8,
#   375,
#   4,
#   82,
#   105,
#   1579,
#   45,
#   84,
#   470,
#   3,
#   82,
#   46,
#   2479,
#   10,
#   3,
#   254,
#   30,
#   168,
#   14,
#   17,
#   421,
#   45,
#   24,
#   12,
#   121,
#   819,
#   3,
#   684,
#   64],
#  [3706],
#  [3706, 29],
#  [3706, 29, 95],
#  [3706, 29, 95, 3],
#  [3706, 29, 95, 3, 69],
#  [3706, 29, 95, 3, 69, 6],
#  [3706, 29, 95, 3, 69, 6, 4],
#  [3706, 29, 95, 3, 69, 6, 4, 1580],
#  [3706, 29, 95, 3, 69, 6, 4, 1580, 497],
#  [3706, 29, 95, 3, 69, 6, 4, 1580, 497, 29],
#  [3706, 29, 95, 3, 69, 6, 4, 1580, 497, 29, 95],
#  [3706, 29, 95, 3, 69, 6, 4, 1580, 497, 29, 95, 3],
#  [3708],
#  [3708, 75],
#  [3708, 75, 92],
#  [3708, 75, 92, 67],
#  [3708, 75, 92, 67, 306],
#  [3708, 75, 92, 67, 306, 28],
#  [3708, 75, 92, 67, 306, 28, 11],
#  [3708, 75, 92, 67, 306, 28, 11, 1159],
#  [3708, 75, 92, 67, 306, 28, 11, 1159, 3],
#  [3708, 75, 92, 67, 306, 28, 11, 1159, 3, 3],
#  [3708, 75, 92, 67, 306, 28, 11, 1159, 3, 3, 132],
#  [3708, 75, 92, 67, 306, 28, 11, 1159, 3, 3, 132, 48],
#  [714],
#  [714, 53],
#  [714, 53, 10],
#  [714, 53, 10, 3],
#  [714, 53, 10, 3, 125],
#  [714, 53, 10, 3, 125, 2],
#  [714, 53, 10, 3, 125, 2, 53],
#  [714, 53, 10, 3, 125, 2, 53, 62],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10, 3],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10, 3, 204],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10, 3, 204, 2],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10, 3, 204, 2, 53],
#  [714, 53, 10, 3, 125, 2, 53, 62, 3, 29, 51, 2, 53, 10, 3, 204, 2, 53, 643],
#  [714,
#   53,
#   10,
#   3,
#   125,
#   2,
#   53,
#   62,
#   3,
#   29,
#   51,
#   2,
#   53,
#   10,
#   3,
#   204,
#   2,
#   53,
#   643,
#   238],
#  [3711],
#  [3711, 484],
#  [3711, 484, 11],
#  [3711, 484, 11, 8],
#  [3711, 484, 11, 8, 956],
#  [3711, 484, 11, 8, 956, 218],
#  [3711, 484, 11, 8, 956, 218, 16],
#  [3711, 484, 11, 8, 956, 218, 16, 305],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173, 43],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173, 43, 276],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173, 43, 276, 126],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173, 43, 276, 126, 10],
#  [3711, 484, 11, 8, 956, 218, 16, 305, 374, 19, 173, 43, 276, 126, 10, 267],
#  [3711,
#   484,
#   11,
#   8,
#   956,
#   218,
#   16,
#   305,
#   374,
#   19,
#   173,
#   43,
#   276,
#   126,
#   10,
#   267,
#   10],
#  [3711,
#   484,
#   11,
#   8,
#   956,
#   218,
#   16,
#   305,
#   374,
#   19,
#   173,
#   43,
#   276,
#   126,
#   10,
#   267,
#   10,
#   11],
#  [3711,
#   484,
#   11,
#   8,
#   956,
#   218,
#   16,
#   305,
#   374,
#   19,
#   173,
#   43,
#   276,
#   126,
#   10,
#   267,
#   10,
#   11,
#   8],
#  [3711,
#   484,
#   11,
#   8,
#   956,
#   218,
#   16,
#   305,
#   374,
#   19,
#   173,
#   43,
#   276,
#   126,
#   10,
#   267,
#   10,
#   11,
#   8,
#   14],
#  [714],
#  [714, 175],
#  [714, 175, 8],
#  [714, 175, 8, 236],
#  [714, 175, 8, 236, 8],
#  [714, 175, 8, 236, 8, 131],
#  [714, 175, 8, 236, 8, 131, 4],
#  [714, 175, 8, 236, 8, 131, 4, 291],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4, 114],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4, 114, 2],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4, 114, 2, 235],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4, 114, 2, 235, 332],
#  [714, 175, 8, 236, 8, 131, 4, 291, 3, 3, 52, 207, 4, 114, 2, 235, 332, 406],
#  [2480],
#  [2480, 24],
#  [2480, 24, 9],
#  [2480, 24, 9, 74],
#  [2480, 24, 9, 74, 26],
#  [2480, 24, 9, 74, 26, 32],
#  [2480, 24, 9, 74, 26, 32, 152],
#  [2480, 24, 9, 74, 26, 32, 152, 62],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26, 32],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26, 32, 297],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26, 32, 297, 62],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26, 32, 297, 62, 23],
#  [2480, 24, 9, 74, 26, 32, 152, 62, 19, 20, 26, 32, 297, 62, 23, 152],
#  [1581],
#  [1581, 2],
#  [1581, 2, 2481],
#  [1581, 2, 2481, 166],
#  [1581, 2, 2481, 166, 215],
#  [1581, 2, 2481, 166, 215, 8],
#  [1581, 2, 2481, 166, 215, 8, 19],
#  [1581, 2, 2481, 166, 215, 8, 19, 2],
#  [1581, 2, 2481, 166, 215, 8, 19, 2, 395],
#  [1581, 2, 2481, 166, 215, 8, 19, 2, 395, 152],
#  [3714],
#  [3714, 3],
#  [3714, 3, 165],
#  [3714, 3, 165, 8],
#  [3714, 3, 165, 8, 25],
#  [3714, 3, 165, 8, 25, 19],
#  [3714, 3, 165, 8, 25, 19, 6],
#  [3714, 3, 165, 8, 25, 19, 6, 140],
#  [3714, 3, 165, 8, 25, 19, 6, 140, 1347],
#  [3714, 3, 165, 8, 25, 19, 6, 140, 1347, 148],
#  [3714, 3, 165, 8, 25, 19, 6, 140, 1347, 148, 5],
#  [3714, 3, 165, 8, 25, 19, 6, 140, 1347, 148, 5, 87],
#  [3714, 3, 165, 8, 25, 19, 6, 140, 1347, 148, 5, 87, 183],
#  [2483],
#  [2483, 125],
#  [2483, 125, 4],
#  [2483, 125, 4, 51],
#  [2483, 125, 4, 51, 89],
#  [2483, 125, 4, 51, 89, 14],
#  [3717],
#  [3717, 519],
#  [3717, 519, 26],
#  [3717, 519, 26, 51],
#  [3717, 519, 26, 51, 2],
#  [3717, 519, 26, 51, 2, 333],
#  [3717, 519, 26, 51, 2, 333, 8],
#  [3717, 519, 26, 51, 2, 333, 8, 4],
#  [716],
#  [716, 17],
#  [716, 17, 70],
#  [716, 17, 70, 1582],
#  [716, 17, 70, 1582, 10],
#  [716, 17, 70, 1582, 10, 1583],
#  [716, 17, 70, 1582, 10, 1583, 29],
#  [716, 17, 70, 1582, 10, 1583, 29, 13],
#  [716, 17, 70, 1582, 10, 1583, 29, 13, 6],
#  [716, 17, 70, 1582, 10, 1583, 29, 13, 6, 195],
#  [716, 17, 70, 1582, 10, 1583, 29, 13, 6, 195, 9],
#  [948],
#  [948, 8],
#  [948, 8, 47],
#  [948, 8, 47, 86],
#  [948, 8, 47, 86, 607],
#  [948, 8, 47, 86, 607, 4],
#  ...]

# %%
y
# Out:
# [63,
#  30,
#  20,
#  17,
#  947,
#  11,
#  8,
#  6,
#  1157,
#  9,
#  71,
#  294,
#  11,
#  146,
#  13,
#  810,
#  105,
#  753,
#  71,
#  2462,
#  8,
#  71,
#  872,
#  374,
#  10,
#  434,
#  22,
#  20,
#  466,
#  15,
#  295,
#  53,
#  55,
#  71,
#  3677,
#  15,
#  54,
#  202,
#  715,
#  4,
#  82,
#  16,
#  37,
#  38,
#  8,
#  30,
#  330,
#  94,
#  8,
#  6,
#  1158,
#  2,
#  102,
#  8,
#  30,
#  330,
#  127,
#  8,
#  6,
#  3678,
#  117,
#  13,
#  11,
#  2463,
#  33,
#  1044,
#  31,
#  83,
#  14,
#  602,
#  12,
#  6,
#  75,
#  1339,
#  120,
#  13,
#  2464,
#  3679,
#  8,
#  314,
#  754,
#  8,
#  639,
#  5,
#  44,
#  145,
#  4,
#  13,
#  683,
#  1340,
#  55,
#  683,
#  3681,
#  14,
#  4,
#  203,
#  6,
#  91,
#  9,
#  435,
#  280,
#  203,
#  6,
#  91,
#  9,
#  3683,
#  8,
#  145,
#  4,
#  13,
#  1341,
#  18,
#  22,
#  3,
#  15,
#  55,
#  4,
#  13,
#  176,
#  18,
#  22,
#  3,
#  15,
#  3684,
#  17,
#  14,
#  1342,
#  192,
#  52,
#  416,
#  2465,
#  715,
#  10,
#  364,
#  3685,
#  181,
#  8,
#  40,
#  6,
#  811,
#  1343,
#  3,
#  47,
#  51,
#  60,
#  323,
#  11,
#  8,
#  169,
#  44,
#  12,
#  640,
#  3686,
#  112,
#  105,
#  1046,
#  8,
#  40,
#  3,
#  51,
#  3687,
#  37,
#  8,
#  22,
#  3,
#  66,
#  11,
#  48,
#  182,
#  22,
#  97,
#  131,
#  4,
#  755,
#  59,
#  124,
#  44,
#  6,
#  1940,
#  175,
#  19,
#  2,
#  75,
#  209,
#  8,
#  3,
#  95,
#  4,
#  467,
#  60,
#  97,
#  131,
#  4,
#  755,
#  11,
#  59,
#  517,
#  29,
#  13,
#  16,
#  213,
#  949,
#  518,
#  40,
#  11,
#  812,
#  19,
#  52,
#  159,
#  90,
#  133,
#  90,
#  80,
#  2,
#  235,
#  10,
#  272,
#  23,
#  3,
#  147,
#  127,
#  273,
#  16,
#  162,
#  160,
#  213,
#  50,
#  103,
#  80,
#  9,
#  49,
#  390,
#  159,
#  2467,
#  66,
#  2,
#  160,
#  213,
#  12,
#  2,
#  63,
#  30,
#  18,
#  1344,
#  168,
#  949,
#  133,
#  5,
#  80,
#  86,
#  5,
#  813,
#  7,
#  274,
#  4,
#  119,
#  11,
#  118,
#  9,
#  49,
#  483,
#  417,
#  106,
#  24,
#  9,
#  49,
#  15,
#  131,
#  4,
#  391,
#  16,
#  93,
#  19,
#  3,
#  141,
#  134,
#  59,
#  56,
#  21,
#  3,
#  134,
#  59,
#  238,
#  47,
#  114,
#  16,
#  2468,
#  238,
#  47,
#  114,
#  10,
#  418,
#  31,
#  214,
#  3,
#  253,
#  5,
#  10,
#  419,
#  18,
#  127,
#  52,
#  56,
#  3,
#  684,
#  187,
#  183,
#  267,
#  97,
#  1047,
#  684,
#  45,
#  127,
#  177,
#  261,
#  344,
#  43,
#  5,
#  70,
#  70,
#  70,
#  128,
#  12,
#  101,
#  56,
#  21,
#  3,
#  50,
#  87,
#  31,
#  29,
#  2469,
#  46,
#  177,
#  16,
#  305,
#  420,
#  177,
#  16,
#  1571,
#  59,
#  5,
#  118,
#  1572,
#  177,
#  814,
#  56,
#  873,
#  6,
#  193,
#  92,
#  5,
#  206,
#  46,
#  106,
#  4,
#  290,
#  3688,
#  345,
#  6,
#  152,
#  641,
#  9,
#  874,
#  4,
#  315,
#  59,
#  4,
#  71,
#  756,
#  19,
#  52,
#  30,
#  106,
#  4,
#  315,
#  59,
#  4,
#  71,
#  3689,
#  3,
#  141,
#  950,
#  11,
#  4,
#  6,
#  951,
#  468,
#  262,
#  3,
#  50,
#  225,
#  11,
#  1941,
#  135,
#  14,
#  13,
#  78,
#  179,
#  78,
#  263,
#  33,
#  78,
#  54,
#  77,
#  176,
#  184,
#  77,
#  135,
#  25,
#  171,
#  19,
#  21,
#  77,
#  226,
#  3,
#  148,
#  22,
#  172,
#  603,
#  575,
#  14,
#  2470,
#  436,
#  405,
#  5,
#  2,
#  202,
#  9,
#  3,
#  135,
#  47,
#  13,
#  346,
#  268,
#  19,
#  21,
#  77,
#  26,
#  66,
#  3,
#  296,
#  952,
#  3,
#  4,
#  65,
#  1050,
#  5,
#  953,
#  4,
#  129,
#  188,
#  5,
#  355,
#  392,
#  344,
#  954,
#  78,
#  5,
#  134,
#  78,
#  2,
#  118,
#  3,
#  26,
#  77,
#  135,
#  14,
#  13,
#  294,
#  67,
#  3,
#  88,
#  453,
#  9,
#  2,
#  112,
#  19,
#  77,
#  29,
#  134,
#  3,
#  6,
#  209,
#  9,
#  78,
#  10,
#  77,
#  275,
#  3,
#  26,
#  2471,
#  93,
#  46,
#  50,
#  291,
#  78,
#  50,
#  156,
#  78,
#  50,
#  1942,
#  5,
#  50,
#  454,
#  53,
#  55,
#  77,
#  26,
#  134,
#  290,
#  28,
#  77,
#  214,
#  3,
#  194,
#  103,
#  78,
#  51,
#  28,
#  77,
#  214,
#  3,
#  437,
#  5,
#  576,
#  78,
#  28,
#  575,
#  14,
#  3690,
#  40,
#  875,
#  11,
#  1573,
#  59,
#  2,
#  815,
#  1943,
#  604,
#  8,
#  6,
#  605,
#  1944,
#  12,
#  3691,
#  135,
#  14,
#  17,
#  331,
#  136,
#  7,
#  2472,
#  4,
#  80,
#  19,
#  7,
#  65,
#  7,
#  17,
#  1945,
#  59,
#  136,
#  7,
#  757,
#  4,
#  1946,
#  816,
#  9,
#  25,
#  8,
#  14,
#  274,
#  44,
#  817,
#  2,
#  816,
#  9,
#  496,
#  8,
#  14,
#  1947,
#  44,
#  817,
#  2,
#  816,
#  9,
#  606,
#  8,
#  14,
#  2473,
#  44,
#  817,
#  5,
#  2,
#  816,
#  9,
#  37,
#  8,
#  14,
#  215,
#  44,
#  3692,
#  8,
#  14,
#  6,
#  876,
#  9,
#  25,
#  19,
#  6,
#  876,
#  9,
#  438,
#  10,
#  214,
#  758,
#  3693,
#  213,
#  75,
#  115,
#  5,
#  6,
#  2475,
#  877,
#  57,
#  8,
#  2,
#  1574,
#  3694,
#  8,
#  22,
#  324,
#  4,
#  74,
#  233,
#  20,
#  15,
#  355,
#  102,
#  3695,
#  25,
#  3,
#  105,
#  365,
#  60,
#  33,
#  28,
#  33,
#  69,
#  136,
#  7,
#  25,
#  3,
#  577,
#  105,
#  818,
#  33,
#  878,
#  7,
#  25,
#  3,
#  12,
#  57,
#  79,
#  56,
#  7,
#  32,
#  14,
#  51,
#  149,
#  102,
#  79,
#  9,
#  393,
#  19,
#  57,
#  12,
#  121,
#  41,
#  8,
#  48,
#  7,
#  33,
#  3,
#  46,
#  1345,
#  10,
#  16,
#  316,
#  245,
#  27,
#  759,
#  8,
#  27,
#  316,
#  46,
#  1345,
#  10,
#  28,
#  7,
#  229,
#  685,
#  16,
#  223,
#  3696,
#  88,
#  642,
#  3,
#  15,
#  760,
#  3,
#  240,
#  1949,
#  1346,
#  9,
#  3698,
#  3,
#  717,
#  42,
#  3,
#  17,
#  48,
#  68,
#  4,
#  25,
#  3699,
#  31,
#  578,
#  955,
#  12,
#  1575,
#  26,
#  66,
#  3,
#  6,
#  1576,
#  120,
#  390,
#  65,
#  10,
#  955,
#  12,
#  6,
#  1950,
#  26,
#  66,
#  3,
#  6,
#  3700,
#  8,
#  12,
#  2,
#  718,
#  9,
#  2,
#  1577,
#  5,
#  11,
#  135,
#  13,
#  605,
#  69,
#  68,
#  4,
#  68,
#  4,
#  134,
#  6,
#  347,
#  33,
#  1578,
#  1577,
#  6,
#  469,
#  3702,
#  3,
#  15,
#  3,
#  10,
#  8,
#  1951,
#  55,
#  162,
#  41,
#  8,
#  48,
#  38,
#  394,
#  31,
#  8,
#  2477,
#  55,
#  2478,
#  3,
#  58,
#  16,
#  348,
#  4,
#  13,
#  579,
#  125,
#  49,
#  686,
#  687,
#  21,
#  3,
#  58,
#  49,
#  4,
#  13,
#  53,
#  579,
#  125,
#  49,
#  53,
#  686,
#  3704,
#  8,
#  375,
#  4,
#  82,
#  105,
#  1579,
#  45,
#  84,
#  470,
#  3,
#  82,
#  46,
#  2479,
#  10,
#  3,
#  254,
#  30,
#  168,
#  14,
#  17,
#  421,
#  45,
#  24,
#  12,
#  121,
#  819,
#  3,
#  684,
#  64,
#  3705,
#  29,
#  95,
#  3,
#  69,
#  6,
#  4,
#  1580,
#  497,
#  29,
#  95,
#  3,
#  3707,
#  75,
#  92,
#  67,
#  306,
#  28,
#  11,
#  1159,
#  3,
#  3,
#  132,
#  48,
#  3709,
#  53,
#  10,
#  3,
#  125,
#  2,
#  53,
#  62,
#  3,
#  29,
#  51,
#  2,
#  53,
#  10,
#  3,
#  204,
#  2,
#  53,
#  643,
#  238,
#  3710,
#  484,
#  11,
#  8,
#  956,
#  218,
#  16,
#  305,
#  374,
#  19,
#  173,
#  43,
#  276,
#  126,
#  10,
#  267,
#  10,
#  11,
#  8,
#  14,
#  3712,
#  175,
#  8,
#  236,
#  8,
#  131,
#  4,
#  291,
#  3,
#  3,
#  52,
#  207,
#  4,
#  114,
#  2,
#  235,
#  332,
#  406,
#  3713,
#  24,
#  9,
#  74,
#  26,
#  32,
#  152,
#  62,
#  19,
#  20,
#  26,
#  32,
#  297,
#  62,
#  23,
#  152,
#  1952,
#  2,
#  2481,
#  166,
#  215,
#  8,
#  19,
#  2,
#  395,
#  152,
#  2482,
#  3,
#  165,
#  8,
#  25,
#  19,
#  6,
#  140,
#  1347,
#  148,
#  5,
#  87,
#  183,
#  3715,
#  125,
#  4,
#  51,
#  89,
#  14,
#  3716,
#  519,
#  26,
#  51,
#  2,
#  333,
#  8,
#  4,
#  3718,
#  17,
#  70,
#  1582,
#  10,
#  1583,
#  29,
#  13,
#  6,
#  195,
#  9,
#  2484,
#  8,
#  47,
#  86,
#  607,
#  4,
#  13,
#  ...]

# %%
len(X), len(y)
# Out:
# (85271, 85271)

# %%
max_len = max(len(X) for X in X)
print(max_len)
# Out:
# 745

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_padded = pad_sequences(X, maxlen=max_len, padding="pre")

# %%
y = np.array(y)

# %%
X_padded.shape
# Out:
# (85271, 745)

# %%
y.shape
# Out:
# (85271,)

# %%
from tensorflow.keras.utils import to_categorical
y_one_hot = to_categorical(y, num_classes=vocab_size)

# %%
y.shape
# Out:
# (85271,)

# %%
y_one_hot.shape
# Out:
# (85271, 10000)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,SimpleRNN, LSTM, Dense

# %%
embedding_dim = 50
rnn_units = 128

# %%
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))

rnn_model.add(SimpleRNN(units=rnn_units))
rnn_model.add(Dense(units=vocab_size, activation="softmax"))

# %%
rnn_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
rnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_model = Sequential()
lstm_model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
lstm_model.add(LSTM(units=rnn_units))
lstm_model.add(Dense(units=vocab_size, activation="softmax"))
lstm_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# epochs = 10
# batch_size = 128

# %%
# histroy = rnn_model.fit(X_padded, y_one_hot, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# %%
# epochs = 100
# batch_size = 128

# history_lstm = lstm_model.fit(
#     X_padded, y_one_hot,
#     epochs=epochs,
#     batch_size=batch_size,
#     validation_split=0.1
# )

# %%
# lstm_model.save("lstm_model.h5")
from tensorflow.keras.models import load_model
lstm_model = load_model("lstm_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
index_to_word = {}
for word , index in word_index.items():
    index_to_word[index] = word

# %%
index_to_word
# Out:
# {1: '<OOV>',
#  2: 'the',
#  3: 'you',
#  4: 'to',
#  5: 'and',
#  6: 'a',
#  7: 'i',
#  8: 'is',
#  9: 'of',
#  10: 'that',
#  11: 'it',
#  12: 'in',
#  13: 'be',
#  14: 'not',
#  15: 'are',
#  16: 'your',
#  17: 'have',
#  18: 'for',
#  19: 'but',
#  20: 'we',
#  21: 'if',
#  22: 'what',
#  23: 'with',
#  24: 'all',
#  25: 'love',
#  26: 'can',
#  27: 'my',
#  28: 'when',
#  29: 'will',
#  30: 'as',
#  31: 'who',
#  32: 'do',
#  33: 'or',
#  34: 'me',
#  35: 'he',
#  36: 'they',
#  37: 'life',
#  38: 'one',
#  39: 'was',
#  40: 'like',
#  41: 'there',
#  42: 'people',
#  43: 'on',
#  44: 'its',
#  45: 'at',
#  46: 'so',
#  47: 'never',
#  48: 'no',
#  49: 'them',
#  50: 'dont',
#  51: 'know',
#  52: 'just',
#  53: 'more',
#  54: 'only',
#  55: 'than',
#  56: 'because',
#  57: 'this',
#  58: 'want',
#  59: 'up',
#  60: 'how',
#  61: 'his',
#  62: 'things',
#  63: 'world',
#  64: 'by',
#  65: 'think',
#  66: 'make',
#  67: 'about',
#  68: 'time',
#  69: 'from',
#  70: 'always',
#  71: 'our',
#  72: 'an',
#  73: 'out',
#  74: 'us',
#  75: 'good',
#  76: 'said',
#  77: 'she',
#  78: 'her',
#  79: 'way',
#  80: 'go',
#  81: 'am',
#  82: 'live',
#  83: 'has',
#  84: 'something',
#  85: 'see',
#  86: 'too',
#  87: 'then',
#  88: 'every',
#  89: 'were',
#  90: 'some',
#  91: 'man',
#  92: 'thing',
#  93: 'heart',
#  94: 'nothing',
#  95: 'get',
#  96: 'him',
#  97: 'youre',
#  98: 'would',
#  99: 'those',
#  100: 'their',
#  101: 'yourself',
#  102: 'other',
#  103: 'let',
#  104: 'into',
#  105: 'without',
#  106: 'much',
#  107: 'im',
#  108: 'could',
#  109: 'had',
#  110: 'someone',
#  111: 'ever',
#  112: 'day',
#  113: 'even',
#  114: 'find',
#  115: 'books',
#  116: 'right',
#  117: 'person',
#  118: 'most',
#  119: 'say',
#  120: 'must',
#  121: 'which',
#  122: 'been',
#  123: 'own',
#  124: 'sometimes',
#  125: 'read',
#  126: 'should',
#  127: 'everything',
#  128: 'believe',
#  129: 'being',
#  130: 'really',
#  131: 'going',
#  132: 'feel',
#  133: 'come',
#  134: 'give',
#  135: 'may',
#  136: 'where',
#  137: 'book',
#  138: 'thats',
#  139: 'tell',
#  140: 'little',
#  141: 'cant',
#  142: 'back',
#  143: 'words',
#  144: 'over',
#  145: 'better',
#  146: 'cannot',
#  147: 'through',
#  148: 'now',
#  149: 'any',
#  150: 'enough',
#  151: 'does',
#  152: 'great',
#  153: 'god',
#  154: 'look',
#  155: 'anything',
#  156: 'change',
#  157: 'another',
#  158: 'many',
#  159: 'remember',
#  160: 'best',
#  161: 'down',
#  162: 'true',
#  163: 'still',
#  164: 'did',
#  165: 'need',
#  166: 'mind',
#  167: 'soul',
#  168: 'well',
#  169: 'until',
#  170: 'each',
#  171: 'again',
#  172: 'else',
#  173: 'why',
#  174: 'long',
#  175: 'truth',
#  176: 'loved',
#  177: 'keep',
#  178: 'very',
#  179: 'first',
#  180: 'moment',
#  181: 'woman',
#  182: 'matter',
#  183: 'doesnt',
#  184: 'before',
#  185: 'men',
#  186: 'others',
#  187: 'once',
#  188: 'human',
#  189: 'fear',
#  190: 'end',
#  191: 'around',
#  192: 'ive',
#  193: 'beautiful',
#  194: 'happy',
#  195: 'kind',
#  196: 'don’t',
#  197: 'die',
#  198: 'girl',
#  199: 'happiness',
#  200: 'made',
#  201: 'take',
#  202: 'two',
#  203: 'become',
#  204: 'learn',
#  205: 'myself',
#  206: 'theres',
#  207: 'got',
#  208: 'hope',
#  209: 'part',
#  210: 'same',
#  211: 'alone',
#  212: 'pain',
#  213: 'friends',
#  214: 'makes',
#  215: 'death',
#  216: 'real',
#  217: 'friend',
#  218: 'inside',
#  219: 'thought',
#  220: 'after',
#  221: 'years',
#  222: 'here',
#  223: 'eyes',
#  224: 'wrong',
#  225: 'understand',
#  226: 'loves',
#  227: 'lives',
#  228: 'reading',
#  229: 'fall',
#  230: 'new',
#  231: 'light',
#  232: 'forever',
#  233: 'while',
#  234: 'dream',
#  235: 'ones',
#  236: 'everyone',
#  237: 'living',
#  238: 'youll',
#  239: 'bad',
#  240: 'lose',
#  241: 'away',
#  242: 'forget',
#  243: 'shall',
#  244: 'hard',
#  245: 'upon',
#  246: 'between',
#  247: 'face',
#  248: 'stop',
#  249: 'write',
#  250: 'dreams',
#  251: 'off',
#  252: 'future',
#  253: 'whole',
#  254: 'might',
#  255: 'maybe',
#  256: 'ourselves',
#  257: 'hell',
#  258: 'looking',
#  259: 'stars',
#  260: 'wanted',
#  261: 'trying',
#  262: 'old',
#  263: 'last',
#  264: 'isnt',
#  265: 'courage',
#  266: 'try',
#  267: 'mean',
#  268: 'together',
#  269: 'doing',
#  270: 'place',
#  271: 'less',
#  272: 'stay',
#  273: 'theyre',
#  274: 'hate',
#  275: 'knows',
#  276: 'earth',
#  277: 'put',
#  278: 'felt',
#  279: 'times',
#  280: 'rather',
#  281: 'often',
#  282: 'work',
#  283: 'night',
#  284: 'trust',
#  285: 'grow',
#  286: 'walk',
#  287: 'says',
#  288: 'saying',
#  289: 'anyone',
#  290: 'smile',
#  291: 'hurt',
#  292: 'story',
#  293: 'listen',
#  294: 'thinking',
#  295: 'far',
#  296: 'laugh',
#  297: 'small',
#  298: 'having',
#  299: 'reality',
#  300: 'means',
#  301: 'women',
#  302: 'sad',
#  303: 'leave',
#  304: 'these',
#  305: 'head',
#  306: 'music',
#  307: 'i’m',
#  308: 'youve',
#  309: 'it’s',
#  310: 'important',
#  311: 'somebody',
#  312: 'against',
#  313: 'feeling',
#  314: 'beauty',
#  315: 'stand',
#  316: 'hand',
#  317: 'done',
#  318: 'reason',
#  319: 'universe',
#  320: 'didnt',
#  321: 'fire',
#  322: 'told',
#  323: 'strong',
#  324: 'happens',
#  325: 'sure',
#  326: 'talk',
#  327: 'word',
#  328: 'himself',
#  329: 'full',
#  330: 'though',
#  331: 'gone',
#  332: 'worth',
#  333: 'point',
#  334: 'door',
#  335: 'broken',
#  336: 'dark',
#  337: 'sit',
#  338: 'wish',
#  339: 'happen',
#  340: 'you’re',
#  341: 'least',
#  342: 'past',
#  343: 'comes',
#  344: 'hold',
#  345: 'takes',
#  346: 'perfect',
#  347: 'stupid',
#  348: 'children',
#  349: 'start',
#  350: 'experience',
#  351: 'power',
#  352: 'yet',
#  353: 'asked',
#  354: 'realize',
#  355: 'making',
#  356: 'behind',
#  357: 'left',
#  358: 'wants',
#  359: 'choose',
#  360: 'lot',
#  361: 'whatever',
#  362: 'lost',
#  363: 'looked',
#  364: 'wont',
#  365: 'knowing',
#  366: 'few',
#  367: 'lie',
#  368: 'different',
#  369: 'hear',
#  370: 'afraid',
#  371: 'jace',
#  372: 'ask',
#  373: 'home',
#  374: 'harry',
#  375: 'impossible',
#  376: 'lies',
#  377: 'open',
#  378: 'easy',
#  379: 'already',
#  380: 'three',
#  381: 'exist',
#  382: 'such',
#  383: 'possible',
#  384: 'use',
#  385: 'thoughts',
#  386: 'within',
#  387: 'days',
#  388: '—',
#  389: 'themselves',
#  390: 'also',
#  391: 'break',
#  392: 'mistakes',
#  393: 'loving',
#  394: 'alive',
#  395: 'next',
#  396: 'happened',
#  397: 'wait',
#  398: 'side',
#  399: 'both',
#  400: 'ill',
#  401: 'secret',
#  402: 'deep',
#  403: 'sleep',
#  404: 'silence',
#  405: 'either',
#  406: 'suffering',
#  407: 'tomorrow',
#  408: 'call',
#  409: 'strength',
#  410: 'help',
#  411: 'meant',
#  412: 'knew',
#  413: 'speak',
#  414: 'itself',
#  415: 'seen',
#  416: 'found',
#  417: 'pretty',
#  418: 'half',
#  419: 'goes',
#  420: 'high',
#  421: 'lived',
#  422: 'darkness',
#  423: 'yours',
#  424: 'choice',
#  425: 'forgive',
#  426: 'respect',
#  427: 'young',
#  428: 'simple',
#  429: 'close',
#  430: 'kill',
#  431: 'beginning',
#  432: 'whats',
#  433: 'perhaps',
#  434: 'show',
#  435: 'success',
#  436: 'arent',
#  437: 'mad',
#  438: 'friendship',
#  439: 'thousand',
#  440: 'crazy',
#  441: 'house',
#  442: 'nobody',
#  443: 'history',
#  444: 'able',
#  445: 'set',
#  446: 'meet',
#  447: 'hands',
#  448: 'rest',
#  449: 'answer',
#  450: 'id',
#  451: 'voice',
#  452: 'dare',
#  453: 'second',
#  454: 'expect',
#  455: 'war',
#  456: 'free',
#  457: 'room',
#  458: 'seems',
#  459: 'somewhere',
#  460: 'care',
#  461: 'couldnt',
#  462: 'fight',
#  463: 'known',
#  464: 'lonely',
#  465: 'family',
#  466: 'truly',
#  467: 'decide',
#  468: 'year',
#  469: 'black',
#  470: 'unless',
#  471: 'begin',
#  472: 'turn',
#  473: 'sun',
#  474: 'body',
#  475: 'today',
#  476: 'enjoy',
#  477: 'child',
#  478: 'fact',
#  479: 'worse',
#  480: 'yes',
#  481: 'freedom',
#  482: 'mother',
#  483: 'actually',
#  484: 'course',
#  485: 'born',
#  486: 'seem',
#  487: 'difference',
#  488: 'dead',
#  489: 'taste',
#  490: 'everybody',
#  491: 'peace',
#  492: 'took',
#  493: '–',
#  494: 'stories',
#  495: 'loneliness',
#  496: 'art',
#  497: 'imagination',
#  498: 'wise',
#  499: 'big',
#  500: 'question',
#  501: 'boy',
#  502: 'learned',
#  503: 'single',
#  504: 'completely',
#  505: 'water',
#  506: 'knowledge',
#  507: 'gives',
#  508: 'hes',
#  509: 'wisdom',
#  510: 'desire',
#  511: 'carry',
#  512: 'gets',
#  513: 'sea',
#  514: 'waste',
#  515: 'bear',
#  516: 'father',
#  517: 'girls',
#  518: 'act',
#  519: 'fool',
#  520: 'persons',
#  521: 'control',
#  522: 'finally',
#  523: 'apart',
#  524: 'special',
#  525: 'quite',
#  526: 'stronger',
#  527: 'imagine',
#  528: 'name',
#  529: 'hurts',
#  530: 'minds',
#  531: 'under',
#  532: 'teach',
#  533: 'school',
#  534: 'nice',
#  535: 'touch',
#  536: 'wake',
#  537: 'tree',
#  538: 'morning',
#  539: 'mine',
#  540: 'ten',
#  541: 'called',
#  542: 'came',
#  543: 'seek',
#  544: 'weve',
#  545: 'sense',
#  546: 'getting',
#  547: 'kiss',
#  548: 'writing',
#  549: 'needs',
#  550: 'deserve',
#  551: 'dance',
#  552: 'front',
#  553: 'greatest',
#  554: 'memories',
#  555: 'sky',
#  556: 'joy',
#  557: 'feet',
#  558: 'used',
#  559: 'nor',
#  560: 'value',
#  561: 'age',
#  562: 'longer',
#  563: 'wouldnt',
#  564: 'certain',
#  565: 'okay',
#  566: 'spend',
#  567: 'run',
#  568: 'clary',
#  569: 'arms',
#  570: 'merely',
#  571: 'hearts',
#  572: 'blood',
#  573: 'short',
#  574: 'met',
#  575: 'shes',
#  576: 'miss',
#  577: 'simply',
#  578: 'thinks',
#  579: 'intelligent',
#  580: 'oh',
#  581: 'wrote',
#  582: 'brave',
#  583: 'whom',
#  584: 'written',
#  585: 'can’t',
#  586: 'cry',
#  587: 'feelings',
#  588: 'storm',
#  589: 'anybody',
#  590: 'poetry',
#  591: 'wonder',
#  592: 'powerful',
#  593: 'magic',
#  594: 'gave',
#  595: 'guy',
#  596: 'step',
#  597: 'burn',
#  598: 'moon',
#  599: 'escape',
#  600: 'passion',
#  601: 'trees',
#  602: 'pleasure',
#  603: 'matters',
#  604: 'fantasy',
#  605: 'necessary',
#  606: 'faith',
#  607: 'late',
#  608: 'leaves',
#  609: 'drink',
#  610: 'avoid',
#  611: 'above',
#  612: 'heard',
#  613: 'along',
#  614: 'travel',
#  615: 'infinite',
#  616: 'throw',
#  617: 'library',
#  618: 'questions',
#  619: 'looks',
#  620: 'usually',
#  621: 'holding',
#  622: 'youd',
#  623: 'instead',
#  624: 'poor',
#  625: 'memory',
#  626: 'hour',
#  627: 'grief',
#  628: 'meaning',
#  629: 'becomes',
#  630: 'hide',
#  631: 'saw',
#  632: 'weak',
#  633: 'falling',
#  634: 'sex',
#  635: 'almost',
#  636: 'play',
#  637: 'shut',
#  638: 'cool',
#  639: 'genius',
#  640: 'hot',
#  641: 'deal',
#  642: 'minute',
#  643: 'places',
#  644: 'dies',
#  645: 'probably',
#  646: 'coming',
#  647: 'painful',
#  648: 'skin',
#  649: 'heaven',
#  650: 'accept',
#  651: 'you’ve',
#  652: 'build',
#  653: 'song',
#  654: 'laughter',
#  655: 'didn’t',
#  656: 'bring',
#  657: 'wind',
#  658: 'remain',
#  659: 'none',
#  660: 'common',
#  661: 'move',
#  662: 'nature',
#  663: 'purpose',
#  664: 'money',
#  665: 'waiting',
#  666: 'except',
#  667: 'air',
#  668: 'kids',
#  669: 'beyond',
#  670: 'losing',
#  671: 'middle',
#  672: 'evil',
#  673: 'tears',
#  674: 'follow',
#  675: 'running',
#  676: 'went',
#  677: 'sweet',
#  678: 'bed',
#  679: 'gods',
#  680: 'they’re',
#  681: 'لا',
#  682: 'و',
#  683: 'absolutely',
#  684: 'fail',
#  685: 'asleep',
#  686: 'fairy',
#  687: 'tales',
#  688: 'large',
#  689: 'angel',
#  690: 'ready',
#  691: 'tried',
#  692: 'therefore',
#  693: 'worst',
#  694: 'mans',
#  695: 'forward',
#  696: 'wonderful',
#  697: 'worry',
#  698: 'that’s',
#  699: 'present',
#  700: 'forgotten',
#  701: 'space',
#  702: 'dying',
#  703: 'whether',
#  704: 'rain',
#  705: 'amazing',
#  706: 'road',
#  707: 'count',
#  708: 'kindness',
#  709: 'eat',
#  710: 'wasnt',
#  711: 'white',
#  712: 'reach',
#  713: 'mouth',
#  714: '“the',
#  715: 'ways',
#  716: '“i',
#  717: 'judge',
#  718: 'eye',
#  719: 'sin',
#  720: 'soon',
#  721: 'spirit',
#  722: 'across',
#  723: 'lord',
#  724: 'terrible',
#  725: 'taken',
#  726: 'silent',
#  727: 'outside',
#  728: 'greater',
#  729: 'idea',
#  730: 'humans',
#  731: 'moving',
#  732: 'hours',
#  733: 'strange',
#  734: 'education',
#  735: 'sight',
#  736: 'learning',
#  737: 'sing',
#  738: 'begins',
#  739: 'fun',
#  740: 'fighting',
#  741: 'religion',
#  742: 'form',
#  743: 'paper',
#  744: 'crying',
#  745: 'piece',
#  746: 'window',
#  747: 'among',
#  748: 'leaving',
#  749: 'cut',
#  750: 'toward',
#  751: 'moments',
#  752: 'songs',
#  753: 'changing',
#  754: 'madness',
#  755: 'mess',
#  756: 'enemies',
#  757: 'needed',
#  758: 'unhappy',
#  759: 'chest',
#  760: 'angry',
#  761: 'problem',
#  762: 'order',
#  763: 'safe',
#  764: 'troubles',
#  765: 'trouble',
#  766: 'whenever',
#  767: 'someday',
#  768: 'mistake',
#  769: 'path',
#  770: 'difficult',
#  771: 'discover',
#  772: 'share',
#  773: 'blue',
#  774: 'fell',
#  775: 'please',
#  776: 'interesting',
#  777: 'figure',
#  778: 'failure',
#  779: 'hundred',
#  780: 'wounds',
#  781: 'given',
#  782: 'fly',
#  783: 'turned',
#  784: 'pretend',
#  785: 'telling',
#  786: 'giving',
#  787: 'stood',
#  788: 'watch',
#  789: 'glass',
#  790: 'summer',
#  791: 'hates',
#  792: 'food',
#  793: 'lips',
#  794: 'protect',
#  795: 'started',
#  796: 'havent',
#  797: 'ability',
#  798: 'easier',
#  799: 'ideas',
#  800: 'rare',
#  801: 'kissed',
#  802: 'fill',
#  803: 'opinion',
#  804: 'instant',
#  805: 'soft',
#  806: 'depends',
#  807: 'هو',
#  808: 'sort',
#  809: 'أن',
#  810: 'changed',
#  811: 'tea',
#  812: 'anyway',
#  813: 'baby',
#  814: 'smiling',
#  815: 'brain',
#  816: 'opposite',
#  817: 'indifference',
#  818: 'problems',
#  819: 'case',
#  820: 'cup',
#  821: 'attempt',
#  822: 'doubt',
#  823: 'ahead',
#  824: 'flower',
#  825: 'characters',
#  826: 'rules',
#  827: 'chance',
#  828: 'boring',
#  829: 'dragons',
#  830: 'risk',
#  831: 'gift',
#  832: 'deeply',
#  833: 'adventure',
#  834: 'walls',
#  835: 'guess',
#  836: 'clothes',
#  837: 'glory',
#  838: 'taught',
#  839: 'he’s',
#  840: 'bird',
#  841: 'fig',
#  842: 'wear',
#  843: 'destroy',
#  844: 'actions',
#  845: 'magnus',
#  846: 'floor',
#  847: 'hair',
#  848: 'survive',
#  849: 'fingers',
#  850: 'force',
#  851: 'ron',
#  852: 'goodbye',
#  853: 'rule',
#  854: 'families',
#  855: 'understanding',
#  856: 'self',
#  857: 'capable',
#  858: 'fox',
#  859: 'stuff',
#  860: 'herself',
#  861: 'burning',
#  862: 'spring',
#  863: 'naked',
#  864: 'sorrow',
#  865: 'doesn’t',
#  866: 'country',
#  867: 'wanting',
#  868: 'talking',
#  869: 'tells',
#  870: 'من',
#  871: 'chamber',
#  872: 'choices',
#  873: 'lifes',
#  874: 'bravery',
#  875: 'nonsense',
#  876: 'lack',
#  877: 'conscience',
#  878: 'pride',
#  879: 'reader',
#  880: 'reads',
#  881: 'lover',
#  882: 'horrible',
#  883: 'belief',
#  884: 'fully',
#  885: 'dumbledore',
#  886: 'constantly',
#  887: 'kept',
#  888: 'allow',
#  889: 'gold',
#  890: 'car',
#  891: 'cats',
#  892: 'blind',
#  893: 'bit',
#  894: 'bigger',
#  895: 'you’ll',
#  896: 'sound',
#  897: '2',
#  898: 'deepest',
#  899: 'warm',
#  900: 'writer',
#  901: 'greatness',
#  902: 'science',
#  903: 'character',
#  904: 'believed',
#  905: 'lucky',
#  906: 'awful',
#  907: 'job',
#  908: 'sorry',
#  909: 'hidden',
#  910: 'cold',
#  911: 'opinions',
#  912: 'easily',
#  913: 'somehow',
#  914: 'complete',
#  915: 'relationship',
#  916: 'surprise',
#  917: 'wed',
#  918: 'dangerous',
#  919: 'promise',
#  920: 'precisely',
#  921: 'realized',
#  922: 'offer',
#  923: 'create',
#  924: 'empty',
#  925: 'wild',
#  926: 'sadness',
#  927: 'lets',
#  928: 'neither',
#  929: 'hit',
#  930: 'killed',
#  931: 'peeta',
#  932: 'i’ve',
#  933: 'enemy',
#  934: 'feels',
#  935: 'tired',
#  936: 'teacher',
#  937: 'corner',
#  938: 'flowers',
#  939: 'missing',
#  940: 'parents',
#  941: 'return',
#  942: 'comfort',
#  943: 'suddenly',
#  944: 'depression',
#  945: 'eternal',
#  946: 'نصف',
#  947: 'created',
#  948: '“it',
#  949: 'theyll',
#  950: 'explain',
#  951: 'six',
#  952: 'cause',
#  953: 'admit',
#  954: 'onto',
#  955: 'sitting',
#  956: 'happening',
#  957: 'staring',
#  958: 'opened',
#  959: 'possibly',
#  960: 'whose',
#  961: 'answers',
#  962: 'drive',
#  963: 'differently',
#  964: 'ignore',
#  965: 'quiet',
#  966: 'clear',
#  967: 'brings',
#  968: 'mate',
#  969: 'yesterday',
#  970: 'till',
#  971: 'dogs',
#  972: 'dust',
#  973: 'fallen',
#  974: 'lead',
#  975: 'fit',
#  976: 'transform',
#  977: 'tessa',
#  978: 'pretending',
#  979: 'taking',
#  980: 'date',
#  981: 'list',
#  982: 'she’s',
#  983: 'pages',
#  984: 'likes',
#  985: 'understood',
#  986: 'favorite',
#  987: 'breath',
#  988: 'pure',
#  989: 'filled',
#  990: 'scars',
#  991: 'ordinary',
#  992: 'grateful',
#  993: 'literature',
#  994: 'sees',
#  995: 'advice',
#  996: 'parts',
#  997: 'simon',
#  998: 'faster',
#  999: 'fine',
#  1000: 'fate',
#  ...}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def predictor(model,tokenizer,text,max_len):
  text = text.lower()

  seq = tokenizer.texts_to_sequences([text])[0]
  seq = pad_sequences([seq], maxlen=max_len, padding='pre')

  pred = model.predict(seq,verbose = 0)
  pred_index = np.argmax(pred)
  return index_to_word[pred_index]

# %%
seed_text = "what are you"
next_word = predictor(lstm_model,tokenizer,seed_text,max_len)
print(next_word)
# Out:
# worrying

# %%
def generate_text(model,tokenizer,seed_text,max_len,n_words):
  for _ in range(n_words):
    next_word = predictor(model,tokenizer,seed_text,max_len)
    if next_word == "":
      break
    seed_text += " " + next_word
  return seed_text

# %%
seed = "are you a "
generated_text = generate_text(lstm_model,tokenizer,seed,max_len,10)
print(generated_text)
# Out:
# are you a  christian must also do that we cannot make the face

# %%
import pickle

# %%
with open("tokenizer.pkl","wb") as f:
  pickle.dump(tokenizer,f)

# %%
with open("max_len.pkl","wb") as f:
  pickle.dump(max_len,f)
